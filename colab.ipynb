# %%
"""
This file only exists for the purpose of being able to run Colab on updated files within VSCode.
"""
# Out:
# '\nThis file only exists for the purpose of being able to run Colab on updated files within VSCode.\n'
